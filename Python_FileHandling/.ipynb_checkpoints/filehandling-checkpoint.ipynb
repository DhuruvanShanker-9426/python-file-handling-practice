# %%
f=open("fruits.txt","r")
c=f.read()
print(c)
# Out:
# Mango is a tasty fruit
# Apple is a delicious fruit
# butterscoth milkshake is the best
# black current is expensive
# strawberry is a tasty and sour fruit

# %%
f.close()

# %%
with open("fruits.txt","r") as af:
    l=af.readlines()
    print(l)
# Out:
# ['Mango is a tasty fruit\n', 'Apple is a delicious fruit\n', 'butterscoth milkshake is the best\n', 'black current is expensive\n', 'strawberry is a tasty and sour fruit']

# %%
len(l)
# Out:
# 5

# %%
for i in l:
    print(i)
# Out:
# Mango is a tasty fruit
#
# Apple is a delicious fruit
#
# butterscoth milkshake is the best
#
# black current is expensive
#
# strawberry is a tasty and sour fruit

# %%
for i in l:
    print(len(i))
# Out:
# 23
# 27
# 34
# 27
# 36

# %%
# File from another folder
file_path="C:\Users\Happy\OneDrive\ドキュメント\Files\example.txt"
# Out:
#   Cell In[12], line 2
#     file_path="C:\Users\Happy\OneDrive\ドキュメント\Files\example.txt"
#               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# File from another folder
file_path=r"C:\Users\Happy\OneDrive\ドキュメント\Files\example.txt"

# %%
with open(file_path,"r") as af:
    l=af.readlines()
    print(l)
# Out:
# ['pokemon\n', 'darling in the franxx\n', 'dragon ball\n', 'solo leveling\n', 'sword art online\n', 'naruto\n', 'fragment flower that blooms with diginity']

# %%
len(l)
# Out:
# 7

# %%
for i in l:
    print(len(i))
# Out:
# 8
# 22
# 12
# 14
# 17
# 7
# 41

# %%
with open(file_path,"r+") as af:
    af.write("Horimiya\n")

# %%
with open(file_path,"r") as f:
    b=f.read()
    print(b)
# Out:
# Horimiya
# rling in the franxx
# dragon ball
# solo leveling
# sword art online
# naruto
# fragment flower that blooms with diginity

# %%
with open(file_path,"a") as f:
    f.write("Horimiya\n")

# %%
with open(file_path,"r") as f:
    b=f.read()
    print(b)
# Out:
# pokemom
# darling in the franxx
# dragon ball
# solo leveling
# sword art online
# naruto
# fragment flower that blooms with diginity
# Horimiya
